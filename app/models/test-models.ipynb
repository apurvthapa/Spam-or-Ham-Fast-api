# %%
import joblib

# %%
model = joblib.load("spam_classifier.joblib")
# Out:
# c:\Users\apurv\Desktop\Study material\fastAPI\spam-ham-classifier\myvenv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\apurv\Desktop\Study material\fastAPI\spam-ham-classifier\myvenv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
model.predict(["Hello? How are you"])[0]
# Out:
# 'ham'

# %%
model.predict(["Congratulations , you won @ rolex "])[0]
# Out:
# 'spam'
